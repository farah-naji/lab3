# %%
spark.conf.set(
    "fs.azure.account.key.goodreadsreviews60104384.dfs.core.windows.net",
    "pZcTKMsN83zedQA3LcYU2xsID/DzMx//bY0Is0yuMyWoXNoHgx1Rb17QRSzW9ksEoZu8KqCQPtOU+ASto/2ySQ=="
)

# %%
curated = spark.read.format("delta").load(
    "abfss://lakehouse@goodreadsreviews60104384.dfs.core.windows.net/gold/curated_reviews/"
)

curated.printSchema()
curated.show(5, truncate=False)
# Out:
# root
#  |-- review_id: string (nullable = true)
#  |-- book_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- author_id: string (nullable = true)
#  |-- author_name: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- rating: long (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- n_votes: long (nullable = true)
#  |-- date_added: date (nullable = true)
#
# +--------------------------------+--------+-----------------------------------------+---------+----------------+--------------------------------+------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------+----------+
# |review_id                       |book_id |title                                    |author_id|author_name     |user_id                         |rating|review_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |language|n_votes|date_added|
# +--------------------------------+--------+-----------------------------------------+---------+----------------+--------------------------------+------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------+----------+
# |073abf39809418df58b99f7d983e0b0f|11769081|The Shape of Desire (Shifting Circle, #1)|28544    |Sharon Shinn    |d7879573928a367edb1d1accf2372810|4     |Some how this fantastical story manages to be wholly absorbing. An immediate, sharp edged love story that feels as dangerous and real as any true-crime thriller.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |eng     |0      |2012-03-31|
# |3730de47e1474172a19a4400976e73dd|13257056|Unstoppable (Tracers, #2.5)              |84181    |Laura Griffin   |d7879573928a367edb1d1accf2372810|4     |A satisfying little novella, Kelsey and Gage are well developed and realistic.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |eng     |0      |2012-03-29|
# |2d3a5caf076017d854bd2f37fa54a8ef|9816552 |The Urban Fantasy Anthology              |1067608  |Peter S. Beagle |d7879573928a367edb1d1accf2372810|4     |A very interesting walk through the history of Urban Fantasy, though definitely the darker, more mythical side of the genre. I have mixed feelings about this anthology, if only because of that story choice. The essays included address everything from Charles de Lint's mythic fiction to paranormal romance, but there was very little by way of a happy ending in sight. Despite the discussion, this anthology still makes the racier and kick ass side of the genre the ugly step-sister, definitive triumph or sex are not invited. \n Still four stars, the stories included are wonderful, and there's a few that I wouldn't have encountered otherwise. Urban Fantasy fans just shouldn't expect to see short stories that look too much like their favorite books, Patricia Briggs and Carrie Vaughn's short stories excepted. \n Full review at All Things Urban Fantasy.|en-US   |1      |2011-07-13|
# |d7965caa5d2144af8c95ab633f889c7b|6767883 |Shady Lady (Corine Solomon, #3)          |835348   |Ann Aguirre     |d7879573928a367edb1d1accf2372810|4     |After completely reversing the ending of HELL FIRE in my head, SHADY LADY was a revelation. Aguirre seems to be trying any number of leading men on for size... and it's working, man. Kel was delicious, though I'm not sure how believable the "new and improved" Corine was.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |eng     |0      |2010-12-05|
# |efa5b39716e3b53d09a5c7b927ff7f33|140082  |Club Dead (Sookie Stackhouse, #3)        |17061    |Charlaine Harris|d7879573928a367edb1d1accf2372810|4     |(1/1/05) \n (5/31/17) Poor Sookie, this is a rough one. Her reaction to Alcide lays some very important breadcrumbs for the end of the series, though.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |en-GB   |0      |2010-06-22|
# +--------------------------------+--------+-----------------------------------------+---------+----------------+--------------------------------+------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------+----------+
# only showing top 5 rows

# %%
# Cell 2: Data Cleaning and Transformation (Final Version)


from pyspark.sql.functions import col, trim, lower, split, size, when, round

df = curated

# 1) Standardize data types
df = (
    df
    .withColumn("review_id", col("review_id").cast("string"))
    .withColumn("book_id", col("book_id").cast("string"))
    .withColumn("author_id", col("author_id").cast("string"))
    .withColumn("user_id", col("user_id").cast("string"))
    .withColumn("rating", col("rating").cast("double"))
    .withColumn("n_votes", col("n_votes").cast("int"))
)

# 2) Handle missing or invalid data
df = (
    df
    .withColumn("n_votes", when(col("n_votes").isNull(), 0).otherwise(col("n_votes")))
    .withColumn("language", when(col("language").isNull(), "unknown").otherwise(col("language")))
    .withColumn("review_text", when(col("review_text").isNull(), "").otherwise(col("review_text")))
    .filter(
        col("rating").isNotNull() &
        col("review_text").isNotNull() &
        col("book_id").isNotNull() &
        col("author_id").isNotNull()
    )
)

# 3) Keep ratings between 1 and 5
df = df.filter((col("rating") >= 1.0) & (col("rating") <= 5.0))

# 4) Trim and normalize text fields
df = (
    df
    .withColumn("title", trim(col("title")))
    .withColumn("author_name", trim(col("author_name")))
    .withColumn("review_text", trim(col("review_text")))
    .withColumn("language", lower(trim(col("language"))))
)

# 5) Compute review length (in words) and remove short reviews
df = df.withColumn("review_length_words", size(split(col("review_text"), r"\s+")))
df = df.filter(col("review_length_words") >= 10)

# 6) Remove duplicates
df = df.dropDuplicates(["review_id"])
df = df.dropDuplicates(["user_id", "book_id"])

print("✅ Cleaning transformations completed successfully!")
# Out:
# ✅ Cleaning transformations completed successfully!

# %%
# Cell 3: Save Cleaned Data to Gold Layer


output_path = "abfss://lakehouse@goodreadsreviews60104384.dfs.core.windows.net/gold/features_v1/"

df.write.format("delta").mode("overwrite").save(output_path)

print("✅ Cleaning complete! Data saved to:", output_path)
print("Total rows after cleaning:", df.count())

df.printSchema()
df.show(10, truncate=False)
# Out:
# ✅ Cleaning complete! Data saved to: abfss://lakehouse@goodreadsreviews60104384.dfs.core.windows.net/gold/features_v1/
# Total rows after cleaning: 13557703
# root
#  |-- review_id: string (nullable = true)
#  |-- book_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- author_id: string (nullable = true)
#  |-- author_name: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- n_votes: integer (nullable = true)
#  |-- date_added: date (nullable = true)
#  |-- review_length_words: integer (nullable = false)
#
# +--------------------------------+--------+---------------------------------------------------+---------+--------------------+--------------------------------+------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------+----------+-------------------+
# |review_id                       |book_id |title                                              |author_id|author_name         |user_id                         |rating|review_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |language|n_votes|date_added|review_length_words|
# +--------------------------------+--------+---------------------------------------------------+---------+--------------------+--------------------------------+------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------+----------+-------------------+
# |e2f7134285c0bb014a5d4a654430eb3a|17020   |13 Little Blue Envelopes (Little Blue Envelope, #1)|10317    |Maureen Johnson     |d10ca87cfc87c5e4b8f61e6546a85153|4.0   |Ginny has a lot more guts than I do - an electronic-deviceless excursion in Europe? I would freak out in the first day, guaranteed. \n That said: it's an excellent journey, and incredibly empowering to watch Ginny discover how to be self-reliant. Awesome read.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |eng     |0      |2012-07-08|43                 |
# |defb0a7909843a9955ba537e49b4eda8|3774496 |War and Peace                                      |128382   |Leo Tolstoy         |309b6bbf8d93c7e8fc25586526fdfda3|3.0   |3.5 \n You don't know how happy I am that I finally finished this book. It's long. I'm uh...not thrilled with Tolstoy's view on women (if Natasha is his idea of a perfect woman, we got issues) but I've been meaning to finish this for ages and I'm proud that I did. It's nice to know what happens after The Great Comet ends. \n Sort of nice. Mostly devastating. \n I still think I prefer Anna Karenina to War and Peace but there are many things I appreciate about W&P. I'll never regret finishing this one.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |en-gb   |1      |2017-06-16|93                 |
# |727c97ce4be24f9492f34a93f8e4e9ea|9479671 |Extras (Uglies, #4)                                |13957    |Scott Westerfeld    |477afe0453bac0e05f49adaa071ee05f|3.0   |Not even close to the first three books in the series. But still not a bad book.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |        |0      |2015-10-24|17                 |
# |223d9e11db432924839d6afba457bae2|7876289 |The Wizard Heir (The Heir Chronicles, #2)          |125308   |Cinda Williams Chima|8b5094db97e37a34c0fa4c094634e05f|2.0   |Seriously, I feel like I'm reading a different book than everybody else. A different series maybe. The first book really annoyed the crap out of me and I mainly read this one because I'd already gotten it from the used book store. \n Two things really bugged me about the first book. First, the language was over-the-top flowery to the point that it often dragged me out of the narrative. This is greatly improved in this book or maybe I'd just gotten used to it. Either way, the writing itself was less jarring, and less trying to draw attention to itself with clever turns of phrase. \n The second thing were the weak and nearly non-existent characterizations. I wish I could say the characterizations improved Jack, main character from the first book, was just a bland kind of good kid. Seph initially shows some inkling of having a personality, but this is quickly overshadowed by the demands of the story. Toward the beginning, we are told Seph is a bit of a troublemaker with a checkered past. But boy is he sure passive about his fate once he arrives at the Havens. Evil headmaster torturing Seph? His solution is to mail out letters to the law firm when he fully well knows the law firm isn't receiving. Why not try to figure out how to stop the torture? Or even try to take on the evil headmaster? Nope, it's time to send more letters to the law firm because that is clearly working for him. \n And THEN they go back to Trinity and it goes from interesting plot to boring and predictable. You know what I don't want to read about? Supposed bad boys living idyllic suburban lives in Ohio and having weird romantic subplots with absolutely no chemistry. \n I think this finishes me up for the series. I have no desire to read anymore.|eng     |1      |2010-09-25|313                |
# |7ed22c1541a12a8f567f959aa50c97e2|9436026 |That Deadman Dance                                 |805409   |Kim Scott           |dee9d09301e66d0af67cbecab5192bf6|4.0   |Strong characters, at times lovely poetic language describing not just the here and now but the connections between man, place, and whale, bird and fish. Strong story too but unnecessarily complicated by a few jumps back and forward in time. Recommended. 4/5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |eng     |0      |2013-01-27|42                 |
# |367a32dd8cb10b28512607b4ae5ca255|10964   |Outlander (Outlander, #1)                          |3617     |Diana Gabaldon      |f5ff066a47acc5c7e6975e4c74bfbcae|4.0   |Hooked into the series. *going to the bookstore to get the rest of the series*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |eng     |0      |2016-08-16|15                 |
# |172447d55ea37142b90349a4351f8bc2|6916963 |Succubus Shadows (Georgina Kincaid, #5)            |137902   |Richelle Mead       |6be1ffef1fe639866621756bc22b0eeb|4.0   |I have to say I don't usually like filler books, and I do feel like this was a bit of a filler book, but I love this series so much that it really didn't matter. I like how Richelle Mead shows you where the characters will probably end up but they never get there the way you think they will. I can't wait to see how this series ends.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |en-us   |0      |2010-06-10|69                 |
# |212e2734fbb72ae6727ca85d3b1e3963|588002  |A Very Long Engagement                             |9144     |Sebastien Japrisot  |3dbb77faac58c03b0821328f9f687503|4.0   |This is one of the rare instances in which I saw the movie before reading the book (it's actually one of my favorite movies!). Compared to the movie, the book is definitely a bit harder to get into at first, only because it is difficult to keep track of everyone. Each solider is arbitrary referred to by his real name, his war name, his prison number, a random childhood/friend-specific nickname, and/or his profession in any given paragraph. I spent quite a bit of time during the first few chapters flipping back and forth in order to try to keep everyone straight & match up names -- I can see how that could easily put people off this book. However, it is definitely worth sticking with it; other than the character name confusion (which possibly may be due to the translation), it is really a lovely story with a heart-wrenching ending. The movie is a solid five stars for me (mostly due to the amazing Audrey Tautou) and the book isn't far behind.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |eng     |0      |2013-11-18|172                |
# |d7abe6ed4396f0f63767deab2f317973|23734628|Carry On                                           |4208569  |Rainbow Rowell      |c10f57d5eeb3f429e9637024696a9df0|3.0   |(Still debating whether it should be 3 or 4 stars...) \n I know this is a book that's really a fanfic of a book series that does not exist, but all I really want is a fanfic of solely Penelope Bunce adventures. She's kinda the only character I really care about.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |eng     |0      |2015-10-04|50                 |
# |365928d7e2547efb9d78f6a0287684a9|10194157|Shadow and Bone (The Grisha, #1)                   |4575289  |Leigh Bardugo       |feabef881417d095c4e62433b0ec3b53|3.0   |3.15 Stars \n I'm trying to figure out where did the emotions in the book get lost. I felt no "giddiness" at all when the kiss scenes happened. I didn't feel excitement when the "battle" scenes happened. \n I think for a fantasy novel this book fell just a bet short. I think what really got me was all the Russia lingo in there. I'm all for different languages. But I couldn't/can't pounce half of the damn words in this book. And the crazy thing is...you kind of need to know which is which. It felt bundled up for me. \n I thought the book was ok, not one of my greatest. I think I went into this book thinking it was going to be epic and it was not at all. But however...I am going to read the next book because it was bought for me and I want to finish the series since I started it. \n wish me luck                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |eng     |2      |2013-12-16|158                |
# +--------------------------------+--------+---------------------------------------------------+---------+--------------------+--------------------------------+------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------+----------+-------------------+
# only showing top 10 rows
